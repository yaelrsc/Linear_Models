# %% [markdown]
# <a href="https://colab.research.google.com/github/yaelrsc/Linear_Models/blob/main/TanquedeIdeas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
db = pd.read_excel('BaseANALISIS.xlsx')

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Columns: 183 entries, nombre to comida_con_grasa
# dtypes: float64(150), int64(21), object(12)
# memory usage: 216.0+ KB

# %%
db.head()
# Out:
#                           nombre  casos_1 control_0  edad_m  talla_m  \
# 0     MURILLO HERN�NDEZ SANTIAGO                  1      36     1.58
# 1  FERN�NDEZ MART�NEZ JESUS YAIR                  1      26     1.66
# 2           VALD�Z ARANA NEREIDA                  1      31     1.69
# 3    CORONA FLORES BLANCA ESTELA                  1      31     1.55
# 4        MONTIEL BARRALES CARMEN                  1      35     1.52
#
#    peso_ant_emb  imc_ant_emb residencia  gesta  para  abortos_  ...  \
# 0          56.0    22.432303         DF      4     3         1  ...
# 1          64.0    23.225432         DF      5     5         0  ...
# 2          78.0    27.309968   Edo. Mex      3     1         1  ...
# 3          82.0    34.131113   Edo. Mex      5     4         0  ...
# 4          51.5    22.290512   Edo. Mex      2     0         0  ...
#
#    pescados_g  embutidos_g  carnesrojas_g leguminosas_g cer_refinados_g  \
# ...

# %%
db.columns
# Out:
# Index(['casos_1 control_0', 'edad_m', 'talla_m', 'peso_ant_emb', 'imc_ant_emb',
#        'residencia', 'gesta', 'para', 'abortos_', 'cesareas_',
#        ...
#        'pescados_g', 'embutidos_g', 'carnesrojas_g', 'leguminosas_g',
#        'cer_refinados_g', 'cer_ref_con_azucar_g', 'cafe_g', 'alcohol_g',
#        'grasas_g', 'comida_con_grasa'],
#       dtype='object', length=182)
